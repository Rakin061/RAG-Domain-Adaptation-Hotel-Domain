# %%
def split_text_into_chunks(text):
    chunks = []
    words = text.split()
    current_chunk = []
    current_length = 0

    for word in words:
        if word.endswith(('.', '?', '!')):
            current_chunk.append(word)
            current_length += 1  # Add 1 for the space
            if current_length > 100:
                chunks.append(' '.join(current_chunk))
                current_chunk = []
                current_length = 0
        else:
            current_chunk.append(word)
            current_length += 1

    if current_chunk:
        chunks.append(' '.join(current_chunk))

    return chunks

# %%
import pandas as pd
import csv
# from Split_to_chunks import split_text_into_chunks

# Initialize the output CSV with headers
with open('knowledgebase_review2.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['title', 'text'])

# Read the CSV file using pandas
df = pd.read_csv('ConversationFromCategory2.csv', encoding='utf-8')

for index, row in df.iterrows():
    title = row['title']
    text = row['text']
    print(title)
    chunks = split_text_into_chunks(text)
    print(index)
    with open('knowledgebase_review2.csv', 'a', newline='') as csvfile:
        writer = csv.writer(csvfile)
        for chunk in chunks:
            writer.writerow([title, chunk])
# Out:
# Miscellaneous:TV_20130702_1505
# 0
# Miscellaneous:TV_20180613_1358
# 1
# Miscellaneous:TV_20210605_0949
# 2
# Miscellaneous:TV_20171206_1157
# 3
# Miscellaneous:TV_20190210_0010
# 4
# Miscellaneous:TV_20110620_2232
# 5
# Miscellaneous:TV_20160801_1337
# 6
# Miscellaneous:TV_20230727_1321
# 7
# Miscellaneous:TV_20191130_1900
# 8
# Miscellaneous:TV_20200529_2024
# 9
# Miscellaneous:TV_20141221_2007
# 10
# Miscellaneous:TV_20121014_0431
# 11
# Miscellaneous:TV_20170119_1404
# 12
# Miscellaneous:TV_20240325_1410
# 13
# Miscellaneous:TV_20120310_1003
# 14
# Miscellaneous:TV_20170511_0215
# 15
# Miscellaneous:TV_20230723_1809
# 16
# Miscellaneous:TV_20150102_1908
# 17
# Miscellaneous:TV_20180222_2136
# 18
# Miscellaneous:TV_20100724_0514
# 19
# Miscellaneous:TV_20130625_1619
# 20
# Miscellaneous:TV_20131010_0248
# 21
# Miscellaneous:TV_20150227_1137
# 22
# Miscellaneous:TV_20231204_2206
# 23
# Miscellaneous:TV_20161022_0824
# 24
# Miscellaneous:TV_20190121_2257
# 25
# ...
